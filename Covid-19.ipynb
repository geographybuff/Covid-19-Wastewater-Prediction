# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
import math
import statistics

# %%
# County codes
fips = pd.read_csv("fips.csv", encoding="mbcs")

# Wastewater COVID-19 concentration data
wastewater = pd.read_csv("wastewater.csv")

# Hospitalized patient number data
hospital = pd.read_csv("hospital.csv")

# County populations
population = pd.read_csv("population.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (9,10,14,15,27,30,31,39,52,53,65,69,80,87,89) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Only select California counties from national directory
fips = fips.loc[fips["state"]=="CA"]

# Remove County from name to make it consistent with hospital and population
fips["name"] = [i.replace(" County", "") for i in list(fips["name"])]

# fips to County dictionary needed to reformat wastewater county list
county_dict = dict(zip(fips["fips"], fips["name"]))

# population dictionary needed to adjust hospitalization numbers for county population
population_dict = dict(zip(population["Entity Name"], population["Estimated Population"]))

# %%
# Some wastewater treatment plants serve two counties. We filter these out
wastewater = wastewater.loc[wastewater["county_names"].str.len()<7]

# Change fips ids to county strings
wastewater["county_names"] = [county_dict[int(i)] for i in list(wastewater["county_names"])]

# %%
print(hospital.columns)
print(fips.columns)
print(population.columns)
print(wastewater.columns)
# Out:
# Index(['county', 'todays_date', 'hospitalized_covid_confirmed_patients',
#        'hospitalized_suspected_covid_patients', 'hospitalized_covid_patients',
#        'all_hospital_beds', 'icu_covid_confirmed_patients',
#        'icu_suspected_covid_patients', 'icu_available_beds'],
#       dtype='object')
# Index(['fips', 'name', 'state'], dtype='object')
# Index(['Entity Name', 'Fiscal Year', 'Estimated Population'], dtype='object')
# Index(['epaid', 'wwtp_name', 'reporting_jurisdiction', 'county_names',
#        'other_jurisdiction', 'zipcode', 'capacity_mgd', 'population_served',
#        'industrial_input', 'stormwater_input', 'influent_equilibrated',
#        'sewage_travel_time', 'institution_type', 'wwtp_jurisdiction',
#        'solids_separation', 'pasteurized', 'time_zone', 'sample_id', 'lab_id',
#        'sample_collect_date', 'sample_collect_time', 'flow_rate',
#        'collection_water_temp', 'sample_type', 'composite_freq',
#        'sample_matrix', 'sample_location', 'sample_location_specify',
#        'collection_storage_time', 'collection_storage_temp', 'pretreatment',
#        'pretreatment_specify', 'concentration_method', 'extraction_method',
#        'pre_conc_storage_time', 'pre_conc_storage_temp',
#        'pre_ext_storage_time', 'pre_ext_storage_temp', 'tot_conc_vol',
#        'ext_blank', 'rec_eff_target_name', 'rec_eff_spike_matrix',
#        'rec_eff_spike_conc', 'inhibition_detect', 'pcr_gene_target',
#        'pcr_gene_target_ref', 'pcr_type', 'lod_ref', 'hum_frac_target_mic',
#        'hum_frac_target_mic_ref', 'hum_frac_target_chem',
#        'hum_frac_target_chem_ref', 'other_norm_name', 'other_norm_ref',
#        'quant_stan_type', 'stan_ref', 'inhibition_method',
#        'num_no_target_control', 'reporting_state', 'test_result_date', 'ph',
#        'conductivity', 'tss', 'equiv_sewage_amt', 'pcr_target_units',
#        'pcr_target_avg_conc', 'pcr_target_std_error', 'pcr_target_cl_95_lo',
#        'pcr_target_cl_95_up', 'pcr_target_below_lod', 'lod_sewage',
#        'ntc_amplify', 'rec_eff_percent', 'inhibition_adjust',
#        'hum_frac_mic_conc', 'hum_frac_mic_unit', 'hum_frac_chem_conc',
#        'hum_frac_chem_unit', 'other_norm_conc', 'other_norm_unit',
#        'quality_flag', 'Sample Location Longitude', 'Sample Location Latitude',
#        'Elevation', 'FACILITY NAME', 'qc_ignore', 'dashboard_ignore',
#        'analysis_ignore', 'major_lab_method', 'major_lab_method_desc',
#        'pcr_target'],
#       dtype='object')

# %%
# Select three columns for analysis, and drop all rows with null values
hospital = hospital.loc[:, ['county', 'todays_date', 'hospitalized_covid_patients']].dropna()

# %%
hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61208 entries, 1285 to 62492
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   county                       61208 non-null  object
#  1   todays_date                  61208 non-null  object
#  2   hospitalized_covid_patients  61208 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.9+ MB

# %%
wastewater.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28155 entries, 0 to 32255
# Data columns (total 91 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   epaid                      27174 non-null  object
#  1   wwtp_name                  28155 non-null  object
#  2   reporting_jurisdiction     28155 non-null  object
#  3   county_names               28155 non-null  object
#  4   other_jurisdiction         0 non-null      float64
#  5   zipcode                    28155 non-null  int64
#  6   capacity_mgd               28155 non-null  float64
#  7   population_served          28155 non-null  int64
#  8   industrial_input           6425 non-null   float64
#  9   stormwater_input           5459 non-null   object
#  10  influent_equilibrated      5459 non-null   object
#  11  sewage_travel_time         4949 non-null   float64
#  12  institution_type           28155 non-null  object
#  13  wwtp_jurisdiction          28155 non-null  object
#  14  solids_separation          6968 non-null   object
#  15  pasteurized                4587 non-null   object
#  16  time_zone                  28155 non-null  object
#  17  sample_id                  28155 non-null  object
#  18  lab_id                     28155 non-null  object
#  19  sample_collect_date        28155 non-null  object
#  20  sample_collect_time        28155 non-null  object
#  21  flow_rate                  5705 non-null   float64
#  22  collection_water_temp      2230 non-null   float64
#  23  sample_type                28155 non-null  object
#  24  composite_freq             4203 non-null   float64
#  25  sample_matrix              28155 non-null  object
#  26  sample_location            28155 non-null  object
#  27  sample_location_specify    2251 non-null   object
#  28  collection_storage_time    716 non-null    float64
#  29  collection_storage_temp    0 non-null      float64
#  30  pretreatment               5712 non-null   object
#  31  pretreatment_specify       718 non-null    object
#  32  concentration_method       28155 non-null  object
#  33  extraction_method          28155 non-null  object
#  34  pre_conc_storage_time      7992 non-null   float64
#  35  pre_conc_storage_temp      8105 non-null   float64
#  36  pre_ext_storage_time       7804 non-null   float64
#  37  pre_ext_storage_temp       7026 non-null   float64
#  38  tot_conc_vol               1227 non-null   float64
#  39  ext_blank                  8797 non-null   object
#  40  rec_eff_target_name        27114 non-null  object
#  41  rec_eff_spike_matrix       27631 non-null  object
#  42  rec_eff_spike_conc         26398 non-null  float64
#  43  inhibition_detect          28155 non-null  object
#  44  pcr_gene_target            28155 non-null  object
#  45  pcr_gene_target_ref        28155 non-null  object
#  46  pcr_type                   28155 non-null  object
#  47  lod_ref                    28155 non-null  object
#  48  hum_frac_target_mic        27407 non-null  object
#  49  hum_frac_target_mic_ref    27407 non-null  object
#  50  hum_frac_target_chem       0 non-null      float64
#  51  hum_frac_target_chem_ref   0 non-null      float64
#  52  other_norm_name            187 non-null    object
#  53  other_norm_ref             187 non-null    object
#  54  quant_stan_type            28155 non-null  object
#  55  stan_ref                   28155 non-null  object
#  56  inhibition_method          28155 non-null  object
#  57  num_no_target_control      28155 non-null  object
#  58  reporting_state            28155 non-null  object
#  59  test_result_date           28155 non-null  object
#  60  ph                         3196 non-null   float64
#  61  conductivity               2766 non-null   float64
#  62  tss                        1848 non-null   float64
#  63  equiv_sewage_amt           4565 non-null   float64
#  64  pcr_target_units           28155 non-null  object
#  65  pcr_target_avg_conc        28155 non-null  object
#  66  pcr_target_std_error       1501 non-null   float64
#  67  pcr_target_cl_95_lo        456 non-null    float64
#  68  pcr_target_cl_95_up        456 non-null    float64
#  69  pcr_target_below_lod       12547 non-null  object
#  70  lod_sewage                 28155 non-null  float64
#  71  ntc_amplify                28155 non-null  object
#  72  rec_eff_percent            28155 non-null  float64
#  73  inhibition_adjust          24021 non-null  object
#  74  hum_frac_mic_conc          27085 non-null  float64
#  75  hum_frac_mic_unit          27085 non-null  object
#  76  hum_frac_chem_conc         0 non-null      float64
#  77  hum_frac_chem_unit         0 non-null      float64
#  78  other_norm_conc            0 non-null      float64
#  79  other_norm_unit            0 non-null      float64
#  80  quality_flag               122 non-null    object
#  81  Sample Location Longitude  5459 non-null   float64
#  82  Sample Location Latitude   5459 non-null   float64
#  83  Elevation                  1103 non-null   float64
#  84  FACILITY NAME              28155 non-null  object
#  85  qc_ignore                  0 non-null      float64
#  86  dashboard_ignore           0 non-null      float64
#  87  analysis_ignore            10 non-null     object
#  88  major_lab_method           3730 non-null   float64
#  89  major_lab_method_desc      3610 non-null   object
#  90  pcr_target                 28155 non-null  object
# dtypes: float64(37), int64(2), object(52)
# memory usage: 19.8+ MB

# %%
for i in range(len(wastewater.columns)):
    print(str(wastewater.columns[i])+": " + str(wastewater[str(wastewater.columns[i])].unique()))
# Out:
# epaid: ['CA0078981' 'CA0038768' '5D150100001' 'CA7000009' 'CA0037648'
#  '5D100105001' 'CA0053813' '5A170102002' 'CA0110604' 'CA0105392'
#  'CA0107409' 'CA0047953' 'CA0038067' '-1' 'CA0038628' 'CA0038539'
#  'CA0109991' 'CA0037958' 'CA0037541' 'CA0037621' 'CA0038369' 'CA0049964'
#  'CA0037834' 'CA0077682' 'CA0037842' 'CA0037575' 'CA0037810' 'CA0037869'
#  'CA0048194' 'CA0077950' 'CA0104477' 'CA0037699' 'CA0078948' 'CA00367869'
#  nan 'CA0107417' 'CA0107611' 'CA0108928' 'CA0105350' 'CA0037702'
#  'CA8000409' 'CA0038776' 'CA0038598' 'CA0048127' 'CA0037851' 'CA0022764'
#  'CA0023345' 'CA0079103' 'CA0079219' 'CA0079049' 'CA0081558' 'CA0084271'
#  'CA0079138' 'CA0079154' 'CA0079243' 'CAS004002' '5A570108001'
#  '5A570104001' '5C240107001']
# wwtp_name: ['AmerValley_Quincy' 'Amer_Canyon_Napa' 'BKERSFLD_P2' 'BKERSFLD_P3'
#  'CALEXICO_CTY' 'CCCSD_WWTP' 'FRSN_CLVS_RWRF' 'LACSD_Jnt' 'LakeCty_SE'
#  'OCSD_P1' 'SBMWD_WWRF' 'SDPU_PtLom'
#  'City of Paso Robles Wastewater Treatment Plant'
#  'Sausalito-Marin City Sanitary District'
#  'Lancaster Water Reclamation Plant'
#  'Central Marin Sanitation Agency - West Railroad'
#  'West County Wastewater District'
#  'City of Hollister Domestic Water Recycling Facility' 'LASAN_Hyp'
#  'Novato Sanitary District'
#  'City of San Mateo & Estero M.I.D. Water Quality Control Plant'
#  'SantaClara_Sun' 'SVCW_WWTP' 'SantaClara_GilMrg' 'PA_ALL' 'SRCSD'
#  'SantaClara_SJ' 'Soscol Water Recycling Facility'
#  'Ellis Creek Water Recycling Facility'
#  'City of San Leandro Water Pollution Control Plant'
#  'City of Santa Cruz WTF - City Influent'
#  'Woodland Water Pollution Control Facility' 'Valley Sanitary District'
#  'Vallejo Flood and Wastewater District Wastewater Treatment Plant'
#  'City of Turlock Regional Water Quality Control Facility'
#  '[Fremont Basin] -  Raymond A. Boege Alvarado WWTP'
#  'Sewerage Agency of Southern Marin Wastewater Treatment Plant'
#  'Los Banos Wastewater Treatment Plant' 'JB Latham Treatment Plant'
#  'Regional Treatment Plant' 'Coastal Treatment Plant'
#  'South Bay International Wastewater Treatment Plant'
#  'Riverside Water Quality Control Plant'
#  'Winters - East Street Pump Station' 'EBMUD'
#  'Regional Water Recycling Plant No.1 (RP-1)'
#  'City of Santa Cruz WTF - County Influent'
#  'Calera Creek Water Recycling Plant' 'Sewer Authority Mid-Coastside'
#  'Central Marin Sanitation Agency'
#  'Monterey One Water - Regional Treatment Plant'
#  'Esparto Wastewater Treatment Facility'
#  '[Newark Basin] - Raymond A. Boege Alvarado WWTP'
#  'Lompoc Regional Wastewater Reclamation Plant'
#  'Las Gallinas Valley Sanitary District'
#  'City of Santa Rosa, Laguna Treatment Plant'
#  'Windsor Wastewater Treatment, Reclamation, and Disposal Facility'
#  'City of Madera, Wastewater Treatment Plant'
#  '[Union City Basin] - Raymond A. Boege Alvarado WWTP'
#  'Modesto Wastewater Primary Treatment Facility'
#  'Merced Wastewater Treatment Plant' 'Davis_WWTP'
#  'Manteca WW Quality Control Facility' 'Mountain House WWTP'
#  'Stockton Regional WW Control Facility' 'Tracy WWTP'
#  'White Slough Water Pollution Control Facility' 'Oxnard_WWTP']
# reporting_jurisdiction: ['CA']
# county_names: ['Plumas' 'Napa' 'Kern' 'Imperial' 'Contra Costa' 'Fresno' 'Los Angeles'
#  'Lake' 'Orange' 'San Bernardino' 'San Diego' 'San Luis Obispo' 'Marin'
#  'San Benito' 'San Mateo' 'Santa Clara' 'Sacramento' 'Sonoma' 'Alameda'
#  'Santa Cruz' 'Yolo' 'Riverside' 'Solano' 'Stanislaus' 'Merced' 'Monterey'
#  'Santa Barbara' 'Madera' 'San Joaquin' 'Ventura']
# other_jurisdiction: [nan]
# zipcode: [95971 94503 93307 93313 92231 94553 93706 90745 95422 92708 92408 92106
#  93446 94965 93534 94901 94801 95023 90293 94945 94404 94089 94065 95020
#  94303 95758 95134 94558 94954 94577 95060 95776 92201 94590 95380 94538
#  94941 93635 92629 92677 92154 92504 95694 94607 91761 94044 94019 93933
#  95627 94560 93436 94903 95407 95492 93637 94587 95351 95341 95337 95391
#  95206 95304 95242 93033]
#   6.70e+00  1.07e+01  9.40e+00  8.60e+00  8.10e+00  6.40e+00  7.60e+00
#   9.80e+00  6.90e+00  7.20e+00  8.40e+00  6.80e+00  8.50e+00  1.24e+01
#   1.03e+01  1.02e+01  9.60e+00  9.30e+00  9.00e+00  9.90e+00  1.01e+01
#   9.20e+00  1.00e+01  1.16e+01  8.90e+00  9.10e+00  1.05e+01  9.70e+00
#   1.06e+01  1.10e+01  9.50e+00  8.80e+00  7.10e+00  7.90e+00  6.30e+00
#   7.30e+00  6.60e+00  1.77e+01  1.89e+01  1.91e+01  1.90e+01  1.87e+01
#   1.73e+01  2.09e+01  2.01e+01  2.10e+01  2.16e+01  2.06e+01  2.38e+01
#   2.37e+01  2.18e+01  2.73e+01  2.63e+01  2.26e+01  2.56e+01  2.61e+01
#   2.83e+01  2.94e+01  2.74e+01  2.72e+01  2.91e+01  3.04e+01  2.35e+01
#   2.68e+01  3.17e+01  3.03e+01  3.15e+01  2.95e+01  2.50e+01  3.07e+01
#   2.46e+01  2.87e+01  2.64e+01  3.32e+01  2.96e+01  2.98e+01  3.30e+01
#   2.75e+01  2.59e+01  2.07e+01  1.63e+01  1.96e+01  2.05e+01  2.89e+01
#   1.83e+01  2.08e+01  2.57e+01  1.75e+01  1.66e+01  1.71e+01  1.68e+01
#   2.77e+01]
# sample_type: ['24-hr flow-weighted composite' '24-hr time-weighted composite' 'grab'
#  '26-hr time-weighted composite' '24-hr manual composite']
# composite_freq: [ nan 3.   1.   2.   4.   0.2  0.25]
# sample_matrix: ['raw wastewater' 'primary sludge' 'post grit removal']
# sample_location: ['wwtp' 'upstream' 'WWTP']
# sample_location_specify: [nan 'Pump Station 2' 'line terminates at headworks of plant'
#  'pump station serving irvington basin'
#  'pump station serving newark basin']
# collection_storage_time: [ nan   2.  51.   3.  98.  26.  76.   4.  58.  10.   1.   5.   0.  73.
#   25.  34.  82.  52.  27.  75.  28. 101.  50.  24.  77.   6.  11.  97.
#   29. 100.  23.  67.  12.   9. 125.]
# collection_storage_temp: [nan]
# pretreatment: ['no' 'yes' nan 'YES' 'NO' 'No']
# pretreatment_specify: [nan 'ferric chloride' 'DNA/RNA Shield, Zymo Research (cat. R1100)']
# concentration_method: ['ceres nanotrap' 'none' 'None'
#  'membrane filtration with acidification and mgcl2'
#  'hollow fiber dead end ultrafiltration']
# extraction_method: ['thermo magmax microbiome ultra nucleic acid isolation kit'
#  'chemagic viral dna/rna 300 kit'
#  'Quick RNA Fecal/soil microbe microprep kit, Zymo Research (Cat. R2040)'
#  'zymo environ water rna kit/ zymo environ water rna kit (cat. r2042)'
#  'Chemagic Viral DNA/RNA 300 Kit'
#  'nuclisens manual magnetic bead extraction kit'
#  '4s method (https://www.protocols.io/view/v-4-direct-wastewater-rna-capture-and-purification-bpdfmi3n)'
#  'qiagen qiaamp buffers with epoch columns'
#  'Thermo MagMAX Microbiome Ultra Nucleic Acid Isolation Kit']
# pre_conc_storage_time: [nan  6. 58. 34. 54. 10. 56. 12. 36. 24. 42.  2.  0.  3.  1.]
# pre_conc_storage_temp: [nan  4.]
#  'Lowest concentration of heat-inactivated SARS-CoV-2 spiked into raw sewage'
#  'The LoD of the Zymo Environ RNA extraction and RT-qPCR method from sample preparation to detection, has been determined.To determine a preliminary LoD, SARS-CoV-2 negative proxy wastewater was used as a matrix and was spiked with whole genome RNA from SARS-CoV-2, strain Muc-IMB-1.The SARS-CoV-2 whole genome RNA was obtained from virus isolated from a COVID-19 positive patient specimen at the University of Freiburg, Germany and quantified using RT-qPCR for use in validation studies.The preliminary LoD study was performed using a manual RNA extraction method on the wastewater samples containing 10-fold dilutions of viral RNA from 0 to 8.33 x 104 GEC/ml.The preliminary LoD was determined to be 83 GEC/ml (20 GEC/rxn), the lowest concentration for which 3/3 independent replicates tested positive.The LoD of the workflow was confirmed for both the manual and automated extraction methods using proxy wastewater as a matrix.Whole genome RNA from SARS-CoV-2 was spiked into negative wastewater samples and 20 replicates were independently processed for LoD determination.The lowest concentration at which all 3 replicates were positive in the preliminary LoD (i.e. 83 GEC/mL) was used as a starting point for the confirmatory LoD study.Testing of 83 GEC/mL could not confirm the tentative LoD.Therefore, concentrations above 83 GEC/mL (increasing by factor 2) were tested until ≥ 19/20 replicates tested positive.The final LoD for both the manual and automated extraction methods was determined to be 83 GEC/ml (21 GEC/rxn) or 83,000 copies/L.'
#  'Standard curves performed for N1/N2 using quantified ATCC SARS-CoV-2 RNA template with in-vitro RNA synthesized using Eurofins G-Block to create working stocks of 1x10^3 copies/ul, titrated down to 8 copies/ul. Our sensitivity falls peaks at processing 1 mL of wastewater with a serial dilution of 20 copies/mL. In a 20 ul elution this represents 80 copies/ mL wastewater or 80,000 copies/ L wastewater'
#  'The LoD of the Zymo Environ RNA extraction and RT-qPCR method from sample preparation to detection, has been determined. To determine a preliminary LoD, SARS-CoV-2 negative proxy wastewater was used as a matrix and was spiked with whole genome RNA from SARS-CoV-2, strain Muc-IMB-1.  The SARS-CoV-2 whole genome RNA was obtained from virus isolated from a COVID-19 positive patient specimen at the University of Freiburg, Germany and quantified using RT-qPCR for use in validation studies.  The preliminary LoD study was performed using a manual RNA extraction method on the wastewater samples containing 10-fold dilutions of viral RNA from 0 to 8.33 x 104 GEC/ml. The preliminary LoD was determined to be 83 GEC/ml (20 GEC/rxn), the lowest concentration for which 3/3 independent replicates tested positive. The LoD of the workflow was confirmed for both the manual and automated extraction methods using proxy wastewater as a matrix.  Whole genome RNA from SARS-CoV-2 was spiked into negative wastewater samples and 20 replicates were independently processed for LoD determination. The lowest concentration at which all 3 replicates were positive in the preliminary LoD (i.e. 83 GEC/mL) was used as a starting point for the confirmatory LoD study. Testing of 83 GEC/mL could not confirm the tentative LoD. Therefore, concentrations above 83 GEC/mL (increasing by factor 2) were tested until ≥ 19/20 replicates tested positive. The final LoD for both the manual and automated extraction methods was determined to be 83 GEC/ml (21 GEC/rxn) or 83,000 copies/L.'
#  'The LoD of the Zymo Environ RNA extraction and RT-qPCR method from sample preparation to detection, has been determined. To determine a preliminary LoD, SARS-CoV-2 negative proxy wastewater was used as a matrix and was spiked with whole genome RNA from SARS-CoV-2, strain Muc-IMB-1. The SARS-CoV-2 whole genome RNA was obtained from virus isolated from a COVID-19 positive patient specimen at the University of Freiburg, Germany and quantified using RT-qPCR for use in validation studies. The preliminary LoD study was performed using a manual RNA extraction method on the wastewater samples containing 10-fold dilutions of viral RNA from 0 to 8.33 x 104 GEC/ml. The preliminary LoD was determined to be 83 GEC/ml (20 GEC/rxn), the lowest concentration for which 3/3 independent replicates tested positive. The LoD of the workflow was confirmed for both the manual and automated extraction methods using proxy wastewater as a matrix. Whole genome RNA from SARS-CoV-2 was spiked into negative wastewater samples and 20 replicates were independently processed for LoD determination. The lowest concentration at which all 3 replicates were positive in the preliminary LoD (i.e. 83 GEC/mL) was used as a starting point for the confirmatory LoD study. Testing of 83 GEC/mL could not confirm the tentative LoD. Therefore, concentrations above 83 GEC/mL (increasing by factor 2) were tested until ≥ 19/20 replicates tested positive. The final LoD for both the manual and automated extraction methods was determined to be 83 GEC/ml (21 GEC/rxn) or 83,000 copies/L.'
#  'The LoD of the Zymo Environ RNA extraction and RT-qPCR method from sample preparation to detection, has been determined.To determine a preliminary LoD, SARS-CoV-2 negative proxy wastewater was used as a matrix and was spiked with whole genome RNA from SARS-CoV-2, strain Muc-IMB-1. The SARS-CoV-2 whole genome RNA was obtained from virus isolated from a COVID-19 positive patient specimen at the University of Freiburg, Germany and quantified using RT-qPCR for use in validation studies.The preliminary LoD study was performed using a manual RNA extraction method on the wastewater samples containing 10-fold dilutions of viral RNA from 0 to 8.33 x 104 GEC/ml.The preliminary LoD was determined to be 83 GEC/ml (20 GEC/rxn), the lowest concentration for which 3/3 independent replicates tested positive.The LoD of the workflow was confirmed for both the manual and automated extraction methods using proxy wastewater as a matrix.Whole genome RNA from SARS-CoV-2 was spiked into negative wastewater samples and 20 replicates were independently processed for LoD determination.The lowest concentration at which all 3 replicates were positive in the preliminary LoD (i.e. 83 GEC/mL) was used as a starting point for the confirmatory LoD study.Testing of 83 GEC/mL could not confirm the tentative LoD.Therefore, concentrations above 83 GEC/mL (increasing by factor 2) were tested until ≥ 19/20 replicates tested positive.The final LoD for both the manual and automated extraction methods was determined to be 83 GEC/ml (21 GEC/rxn) or 83,000 copies/L.'
#  'We used 3 droplets as a minimum for a positive detection'
#  'Steele et al. 2018 Water Research DOI: 10.1016/j.watres.2018.01.056  based on BioRad QuantaSoft Manual formula point estimate for 3 positve droplets'
#  'MIQE guidelines found in Bustin et al 2009'
#  'Wu, et al. 2020. SARS-CoV-2 RNA concentrations in wastewater foreshadow dynamics and clinical presentation of new COVID-19 cases. Science of The Total Environment 2022; doi: https://doi.org/10.1016/j.scitotenv.2021.150121'
#  'Contact GTM']
# hum_frac_target_mic: ['pepper mild mottle virus' nan 'Pepper mild mottle virus']
# hum_frac_target_mic_ref: ['ACS EST Water 2021, 1, 1955?1965'
#  'E.M. Symonds, Karena H. Nguyen, V.J. Harwood, M. Breitbart,Pepper mild mottle virus: A plant pathogen with a greater purpose in (waste)water treatment development and public health management,Water Research,Volume 144,2018,Pages 1-12,ISSN 0043-1354.'
#  nan
#  'Kitajima et al. 2014 Sci Tot Env https://doi.org/10.1016/j.scitotenv.2014.04.087'
#  'Haramoto E, Kitajima M, Kishida N, Konno Y, Katayama H, Asami M, Akiba M. Occurrence of pepper mild mottle virus in drinking water sources in Japan. 2013. Appl Environ Microbiol'
#  'Zhang T, Breitbart M, Lee WH, Run JQ, Wei CL, Soh SW, Hibberd ML, Liu ET, Rohwer F, Ruan Y. RNA viral community in human feces: prevalence of plant pathogenic viruses. PLoS Biol. 2006 Jan;4(1):e3. doi: 10.1371/journal.pbio.0040003. PMID: 16336043; PMCID: PMC1310650.'
#  'dx.doi.org/10.17504/protocols.io.e6nvw5orwvmk/v5']
# hum_frac_target_chem: [nan]
# hum_frac_target_chem_ref: [nan]
# other_norm_name: [nan 'Rnase P' 'RNase P']
# other_norm_ref: [nan
#  'HeLa spike-in utilizing RNase P as an internal target for  multiplex system']
# quant_stan_type: ['rna' 'RNA' 'DNA' 'dna']
# stan_ref: ['dx.doi.org/10.17504/protocols.io.b2mjqc4n'
#  'synthetic DNA oligo purchased from IDT' 'Produced in-house'
#  'https://www.atcc.org/products/all/VR-3276SD.aspx'
#  '2019-nCoV_N_positive controls https://www.idtdna.com/pages/landing/coronavirus-research-reagents/cdc-assays'
#  '2019-nCoV_N_Positive Control (https://www.idtdna.com/pages/landing/coronavirus-research-reagents/cdc-assays)'
#  'Lee, et al. 2021. Quantitative SARS-CoV-2 Alpha Variant B.1.1.7 Tracking in Wastewater by Allele-Specific RT-qPCR. Environ. Sci. Technol. Lett. 2021, 8, 8, 675–682; doi: https://doi.org/10.1021/acs.estlett.1c00375'
#  'GTM N1 Control']
# inhibition_method: ['none' 'In vitro transcribed RNA that is not found in nature'
#  'HeLa Cell Spike-in; positive control with 50,000 cells along with spike-in of 50,000 cells per sample prep. Measuring delta Ct.'
#  'We titrated solutions with varying concentrations of solids to identify a concentration at which inhibition of the SARS-CoV-2 assays was minimized'
#  'Armored RNA HepG after EPA Method 1612'
#  'RNA is assayed undiluted (1x) and at 5-fold dilution (5x), and the effective quantities are compared. The higher value is reported unless only one of the dilutions amplifies'
#  'Perchetti, et al. 2020. Multiplexing primer/probe sets for detection of SARS-CoV-2 by qRT-PCR. J Clin Virol 129: 104499; doi: https://doi.org/10.1016/j.jcv.2020.104499'
#  'https://www.protocols.io/view/high-throughput-pre-analytical-processing-of-waste-kxygxpod4l8j/v2']
# num_no_target_control: ['3' 'more than 3' '2']
# reporting_state: ['CA']
# test_result_date: ['9/12/2022' '9/20/2022' '9/26/2022' '10/6/2022' '10/11/2022' '10/14/2022'
#  '10/28/2022' '11/4/2022' '11/14/2022' '11/18/2022' '11/29/2022'
#  '12/1/2022' '12/9/2022' '12/22/2022' '1/4/2023' '1/9/2023' '1/19/2023'
#  '1/24/2023' '1/26/2023' '2/2/2023' '2/13/2023' '2/22/2023' '2/24/2023'
#  '3/7/2023' '3/13/2023' '3/21/2023' '3/24/2023' '4/7/2023' '4/13/2023'
#  '11/9/2022' '11/17/2022' '11/22/2022' '11/23/2022' '11/30/2022'
#  '12/6/2022' '12/8/2022' '12/12/2022' '12/19/2022' '12/15/2022'
#  5.17000000e+04 4.66000000e+04 4.18000000e+04 5.39000000e+04
#  4.58000000e+04 4.62000000e+04 1.57000000e+04 3.85000000e+04
#  3.58000000e+04 4.67000000e+04 2.25000000e+04 4.23000000e+04
#  2.65000000e+04 4.84000000e+04 1.88000000e+04 8.33000000e+04
#  4.07000000e+04 3.53000000e+04 2.99000000e+04 2.10000000e+04
#  3.02000000e+04 3.52000000e+04 3.92000000e+04 3.22000000e+04
#  2.40000000e+04 3.78000000e+04 3.40000000e+04 4.34000000e+04
#  3.75000000e+04 3.21000000e+04 4.48000000e+04 3.46000000e+04
#  2.88000000e+04 3.83000000e+04]
# ntc_amplify: ['no' 'No' 'yes']
# rec_eff_percent: [ 66.82514558  78.93781648  63.51873553 ... 181.         260.
#  196.        ]
# inhibition_adjust: [nan 'no' 'yes' 'Yes' 'No']
# hum_frac_mic_conc: [2.96634684e+08 5.24904606e+08 5.86033691e+08 ... 2.28000000e+09
#  4.53000000e+08 4.69000000e+09]
# hum_frac_mic_unit: ['copies/L wastewater' 'copies/g dry sludge' nan
#  'log10 copies/L wastewater']
# hum_frac_chem_conc: [nan]
# hum_frac_chem_unit: [nan]
# other_norm_conc: [nan]
# other_norm_unit: [nan]
# quality_flag: [nan 'yes' 'no']
# Sample Location Longitude: [-120.918114  -122.2771    -118.505     -119.077618   115.5140683
#  -122.06642   -119.890539  -117.938     -122.62739   -117.2881671
#  -117.208048           nan -118.286     -117.246688  -115.5140683]
# Sample Location Latitude: [39.935799   38.1879     35.324      35.281072   32.6707032  37.99649
#  36.70638    33.69263    38.98559    34.07713357 32.729788           nan
#  33.801      32.681041  ]
# Elevation: [ nan 20.  16.2 21.6]
# FACILITY NAME: ['American Valley Community Services District'
#  'City of American Canyon Water Reclamation Facility'
#  'City of Bakersfield Plant #2' 'City of Bakersfield Plant #3'
#  'Calexico City WWTP'
#  'Central Contra Costa Sanitary District Wastewater Treatment Plant'
#  'Fresno/Clovis RWRF' 'Joint Water Pollution Control Plant'
#  'City of Clearlake'
#  'OC San (Orange County Sanitation District) Reclamation Plant No. 1'
#  'Margaret H Chandler WWRF, San Bernardino'
#  'San Diego EW Blom Point Loma WWTP'
#  'City of Paso Robles Wastewater Treatment Plant'
#  'Sausalito-Marin City Sanitary District'
#  'Lancaster Water Reclamation Plant'
#  'Central Marin Sanitation Agency - West Railroad'
#  'West County Wastewater District'
#  'City of Hollister Domestic Water Recycling Facility'
#  'Hyperion Water Reclamation Facility' 'Novato Sanitary District'
#  'City of San Mateo & Estero M.I.D. Water Quality Control Plant'
#  'Sunnyvale Santa Clara' 'Silicon Valley' 'Gilroy Santa Clara'
#  'Palo Alto All WWTP' 'Sacramento Regional County Sanitation District'
#  'San Jose Santa Clara' 'Soscol Water Recycling Facility'
#  'Ellis Creek Water Recycling Facility'
#  'City of San Leandro Water Pollution Control Plant'
#  'City of Santa Cruz WTF - City Influent'
#  'Woodland Water Pollution Control Facility' 'Valley Sanitary District'
#  'Vallejo Flood and Wastewater District Wastewater Treatment Plant'
#  'City of Turlock Regional Water Quality Control Facility'
#  '[Fremont Basin] -  Raymond A. Boege Alvarado WWTP'
#  'Sewerage Agency of Southern Marin Wastewater Treatment Plant'
#  'Los Banos Wastewater Treatment Plant' 'JB Latham Treatment Plant'
#  'Regional Treatment Plant' 'Coastal Treatment Plant'
#  'South Bay International Wastewater Treatment Plant'
#  'Riverside Water Quality Control Plant'
#  'Winters - East Street Pump Station'
#  'East Bay Municipal Utility District Main Wastewater Treatment Plant'
#  'Regional Water Recycling Plant No.1 (RP-1)'
#  'City of Santa Cruz WTF - County Influent'
#  'Calera Creek Water Recycling Plant' 'Sewer Authority Mid-Coastside'
#  'Central Marin Sanitation Agency'
#  'Monterey One Water - Regional Treatment Plant'
#  'Esparto Wastewater Treatment Facility'
#  '[Newark Basin] - Raymond A. Boege Alvarado WWTP'
#  'Lompoc Regional Wastewater Reclamation Plant'
#  'Las Gallinas Valley Sanitary District'
#  'City of Santa Rosa, Laguna Treatment Plant'
#  'Windsor Wastewater Treatment, Reclamation, and Disposal Facility'
#  'City of Madera, Wastewater Treatment Plant'
#  '[Union City Basin] - Raymond A. Boege Alvarado WWTP'
#  'Modesto Wastewater Primary Treatment Facility'
#  'Merced Wastewater Treatment Plant' 'City of Davis WWTP'
#  'Manteca WW Quality Control Facility' 'Mountain House WWTP'
#  'Stockton Regional WW Control Facility' 'Tracy WWTP'
#  'White Slough Water Pollution Control Facility'
#  'Oxnard Wastewater Treatment Plant']
# qc_ignore: [nan]
# dashboard_ignore: [nan]
# analysis_ignore: [nan 'yes']
# major_lab_method: [ 1. nan  4.]
# major_lab_method_desc: ['this lab uses a lab method distinct from other labs in this reporting jurisdiction'
#  nan]
# pcr_target: ['sars-cov-2' 'omicron' 'hMPXV' 'hMPXV Clade II']

# %%
wastewater["hum_frac_mic_unit"].value_counts()
# Out:
# copies/g dry sludge          22450
# copies/L wastewater           4100
# log10 copies/L wastewater      535
# Name: hum_frac_mic_unit, dtype: int64

# %%
wastewater["pcr_target_units"].value_counts()
# Out:
# copies/g dry sludge          22450
# copies/L wastewater           4722
# log10 copies/L wastewater      857
# copies/l wastewater            126
# Name: pcr_target_units, dtype: int64

# %%
# Select columns for wastewater analysis
wastewater = wastewater.loc[:, ["county_names", "sample_collect_date", "rec_eff_spike_conc", "pcr_target_units", "pcr_target_avg_conc", "pcr_target", "hum_frac_mic_unit", "hum_frac_mic_conc"]].dropna()

# %%
wastewater.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26220 entries, 0 to 31539
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   county_names         26220 non-null  object
#  1   sample_collect_date  26220 non-null  object
#  2   rec_eff_spike_conc   26220 non-null  float64
#  3   pcr_target_units     26220 non-null  object
#  4   pcr_target_avg_conc  26220 non-null  object
#  5   pcr_target           26220 non-null  object
#  6   hum_frac_mic_unit    26220 non-null  object
#  7   hum_frac_mic_conc    26220 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 1.8+ MB

# %%
# Only select wastewater columns with a copies/g unit because we don't have a g/L unit conversion
# Eliminate units columns from out analysis because we won't need them anymore
wastewater = wastewater[(wastewater['pcr_target_units'] == 'copies/g dry sludge') & (wastewater['hum_frac_mic_unit'] == 'copies/g dry sludge')].loc[:, ["county_names", "sample_collect_date", "rec_eff_spike_conc", "pcr_target_avg_conc", "pcr_target", "hum_frac_mic_conc"]]

# %%
wastewater.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21734 entries, 5026 to 31539
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   county_names         21734 non-null  object
#  1   sample_collect_date  21734 non-null  object
#  2   rec_eff_spike_conc   21734 non-null  float64
#  3   pcr_target_avg_conc  21734 non-null  object
#  4   pcr_target           21734 non-null  object
#  5   hum_frac_mic_conc    21734 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 1.2+ MB

# %%
set(wastewater["county_names"])
# Out:
# {'Alameda',
#  'Contra Costa',
#  'Los Angeles',
#  'Madera',
#  'Marin',
#  'Merced',
#  'Monterey',
#  'Napa',
#  'Orange',
#  'Riverside',
#  'Sacramento',
#  'San Benito',
#  'San Bernardino',
#  'San Diego',
#  'San Luis Obispo',
#  'San Mateo',
#  'Santa Barbara',
#  'Santa Clara',
#  'Santa Cruz',
#  'Solano',
#  'Sonoma',
#  'Stanislaus',
#  'Yolo'}

# %%
# Limit hospital dataset to the counties where we have wastewater data
hospital = hospital[(hospital["county"].isin(set(wastewater["county_names"].tolist())))]

# %%
hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25139 entries, 1289 to 62490
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   county                       25139 non-null  object
#  1   todays_date                  25139 non-null  object
#  2   hospitalized_covid_patients  25139 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 785.6+ KB

# %%
# Count unique pairings of hospital/date.
len(set([(hospital.iloc[i]["county"], hospital.iloc[i]["todays_date"]) for i in range(len(hospital))]))
#This value equals the size of hospital, so the hospital data is aggregated by county.
# Out:
# 25139

# %%
hospital["todays_date"]
# Out:
# 1289     2020-04-21
# 1290     2020-04-21
# 1291     2020-04-21
# 1298     2020-04-21
# 1300     2020-04-21
#             ...
# 62485    2023-04-18
# 62486    2023-04-18
# 62487    2023-04-18
# 62488    2023-04-18
# 62490    2023-04-18
# Name: todays_date, Length: 25139, dtype: object

# %%
wastewater["sample_collect_date"]
# Out:
# 5026     1/11/2022
# 5027     1/11/2022
# 5028     1/11/2022
# 5029     1/13/2022
# 5030     1/13/2022
#            ...
# 31535    6/10/2022
# 31536    6/10/2022
# 31537     6/7/2022
# 31538     6/7/2022
# 31539     6/9/2022
# Name: sample_collect_date, Length: 21734, dtype: object

# %%
# We need to convert the dates to a common format
hospital["todays_date"] = [datetime.strptime(hospital.iloc[i]["todays_date"], '%Y-%m-%d') for i in range(len(hospital))]

# %%
wastewater["sample_collect_date"] = [datetime.strptime(wastewater.iloc[i]["sample_collect_date"], '%m/%d/%Y') for i in range(len(wastewater))]

# %%
hospital = hospital.sort_values(by='todays_date', ascending=True)

# %%
wastewater = wastewater.sort_values(by='sample_collect_date', ascending=True)

# %%
hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25139 entries, 1289 to 62490
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   county                       25139 non-null  object
#  1   todays_date                  25139 non-null  datetime64[ns]
#  2   hospitalized_covid_patients  25139 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 785.6+ KB

# %%
wastewater.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21734 entries, 25577 to 10479
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   county_names         21734 non-null  object
#  1   sample_collect_date  21734 non-null  datetime64[ns]
#  2   rec_eff_spike_conc   21734 non-null  float64
#  3   pcr_target_avg_conc  21734 non-null  object
#  4   pcr_target           21734 non-null  object
#  5   hum_frac_mic_conc    21734 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 1.2+ MB

# %%
# Test the functionality of adding six days to a datetime64[ns] datatype
print(hospital.iloc[133]["todays_date"])
print(hospital.iloc[133]["todays_date"]+np.timedelta64(6, 'D'))
# Out:
# 2020-04-26 00:00:00
# 2020-05-02 00:00:00

# %%
# Create a new column for hospital overcrowding in the wastewater dataframe
wastewater['hospital_overcrowding'] = np.nan

# %%
# New hospital column for hospitalized covid suspected patients per capita
hospital["hospitalized_per_capita"] = [hospital.iloc[i]["hospitalized_covid_patients"]/population_dict[hospital.iloc[i]["county"]] for i in range(len(hospital))]

# %%
# Iterate through each row of the wastewater dataframe
for index, row in wastewater.iterrows():
    # Find the corresponding county and date in the hospital dataframe
    county = row['county_names']
    date = row['sample_collect_date'] + pd.Timedelta(days=6)
    hospital_row = hospital[(hospital['county'] == county) & (hospital['todays_date'] >= date - pd.Timedelta(hours=13)) & (hospital['todays_date'] <= date + pd.Timedelta(hours=13))]
    
    # If a corresponding row is found, copy the hospitalized_covid_patients value into the wastewater dataframe
    if not hospital_row.empty:
        wastewater.loc[index, 'hospital_overcrowding'] = hospital_row["hospitalized_per_capita"].values[0]
    else:
        wastewater.loc[index, 'hospital_overcrowding'] = None

# %%
wastewater.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21734 entries, 25577 to 10479
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   county_names           21734 non-null  object
#  1   sample_collect_date    21734 non-null  datetime64[ns]
#  2   rec_eff_spike_conc     21734 non-null  float64
#  3   pcr_target_avg_conc    21734 non-null  object
#  4   pcr_target             21734 non-null  object
#  5   hum_frac_mic_conc      21734 non-null  float64
#  6   hospital_overcrowding  21638 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 1.8+ MB

# %%
hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25139 entries, 1289 to 62490
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   county                       25139 non-null  object
#  1   todays_date                  25139 non-null  datetime64[ns]
#  2   hospitalized_covid_patients  25139 non-null  float64
#  3   hospitalized_per_capita      25139 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 982.0+ KB

# %%
# drops rows that do not have a hospital overcrowding value for six days later
wastewater = wastewater.dropna()

# convert the 'pcr_target_avg_conc' column to float data type
wastewater['pcr_target_avg_conc'] = wastewater['pcr_target_avg_conc'].astype(float)

# perform one hot encoding on the 'pcr_target' column of the wastewater dataframe
wastewater = pd.concat([wastewater, pd.get_dummies(wastewater['pcr_target'])], axis=1)

# %%
wastewater.describe()
# Out:
#        pcr_target_avg_conc  hum_frac_mic_conc  hospital_overcrowding  \
# count         2.163800e+04       2.163800e+04           21638.000000
# mean          1.790351e+05       1.356503e+09               0.000093
# std           3.108033e+05       3.459123e+09               0.000067
# min           0.000000e+00       1.938805e+07               0.000000
# 25%           9.086181e+03       5.954860e+08               0.000053
# 50%           8.401463e+04       9.611537e+08               0.000081
# 75%           2.376014e+05       1.520000e+09               0.000116
# max           1.141656e+07       2.440000e+11               0.000741
#
#               hMPXV  hMPXV Clade II       omicron    sars-cov-2
# count  21638.000000    21638.000000  21638.000000  21638.000000
# mean       0.067982        0.107727      0.213375      0.610916
# std        0.251721        0.310043      0.409699      0.487554
# min        0.000000        0.000000      0.000000      0.000000
# 25%        0.000000        0.000000      0.000000      0.000000
# 50%        0.000000        0.000000      0.000000      1.000000
# 75%        0.000000        0.000000      0.000000      1.000000
# max        1.000000        1.000000      1.000000      1.000000

# %%
wastewater.drop("rec_eff_spike_conc", axis=1, inplace=True)
wastewater.drop("county_names", axis=1, inplace=True)
# model must be date agnostic and must only rely on predictive indicators
wastewater.drop("sample_collect_date", axis=1, inplace=True)
# made redundant by one hot encoding
wastewater.drop("pcr_target", axis=1, inplace=True)

# %%
# Concentrations must be log scaled because they follow a log distribution
wastewater["pcr_target_avg_conc"] = np.log(wastewater["pcr_target_avg_conc"]+10)
wastewater["hum_frac_mic_conc"] = np.log(wastewater["hum_frac_mic_conc"])

# %%
print("RMSE of predicting the median for all values: ")
median = statistics.median(list(wastewater["hospital_overcrowding"]))
print(np.sqrt(mean_squared_error(list(wastewater["hospital_overcrowding"]), [median for i in range(len(wastewater))])))
# Out:
# RMSE of predicting the median for all values:
# 6.806749259251654e-05

# %%
# feature label split
X = wastewater.drop("hospital_overcrowding", axis=1).to_numpy()
y = wastewater["hospital_overcrowding"].to_numpy()
# scale X to a standard distribution
scaler_X = StandardScaler()
scaler_X.fit(X)
scaler_X.transform(X)
# scale y to a [0, 1] interval
y_min = np.min(y)
y_max = np.max(y)
y = (y-y_min)/(y_max-y_min)
# 77% train 23% test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.23, random_state=1)

# %%
model = MLPRegressor(hidden_layer_sizes=(500, 200, 20),
                     activation = "relu",
                     learning_rate_init=0.001,
                     random_state=1,
                     max_iter=500,
                     verbose=True,
                     solver = "adam",
                     tol=1e-6,
                     batch_size=64,
                     n_iter_no_change=20)
regr = model.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.00673350
# Iteration 2, loss = 0.00416029
# Iteration 3, loss = 0.00421474
# Iteration 4, loss = 0.00415805
# Iteration 5, loss = 0.00416131
# Iteration 6, loss = 0.00401864
# Iteration 7, loss = 0.00420282
# Iteration 8, loss = 0.00397737
# Iteration 9, loss = 0.00390924
# Iteration 10, loss = 0.00391063
# Iteration 11, loss = 0.00397927
# Iteration 12, loss = 0.00390165
# Iteration 13, loss = 0.00388436
# Iteration 14, loss = 0.00381300
# Iteration 15, loss = 0.00388055
# Iteration 16, loss = 0.00380330
# Iteration 17, loss = 0.00379774
# Iteration 18, loss = 0.00385399
# Iteration 19, loss = 0.00384864
# Iteration 20, loss = 0.00375278
# Iteration 21, loss = 0.00376391
# Iteration 22, loss = 0.00374677
# Iteration 23, loss = 0.00372280
# Iteration 24, loss = 0.00372969
# Iteration 25, loss = 0.00374289
# Iteration 26, loss = 0.00373712
# Iteration 27, loss = 0.00372785
# Iteration 28, loss = 0.00371285
# Iteration 29, loss = 0.00371209
# Iteration 30, loss = 0.00370845
# Iteration 31, loss = 0.00371329
# Iteration 32, loss = 0.00372184
# Iteration 33, loss = 0.00370204
# Iteration 34, loss = 0.00371240
# Iteration 35, loss = 0.00370120
# Iteration 36, loss = 0.00368499
# Iteration 37, loss = 0.00368377
# Iteration 38, loss = 0.00369899
# Iteration 39, loss = 0.00368402
# Iteration 40, loss = 0.00368257
# Iteration 41, loss = 0.00369026
# Iteration 42, loss = 0.00368649
# Iteration 43, loss = 0.00367711
# Iteration 44, loss = 0.00366776
# Iteration 45, loss = 0.00366942
# Iteration 46, loss = 0.00368462
# Iteration 47, loss = 0.00366062
# Iteration 48, loss = 0.00367083
# Iteration 49, loss = 0.00366177
# Iteration 50, loss = 0.00367728
# Iteration 51, loss = 0.00365015
# Iteration 52, loss = 0.00365927
# Iteration 53, loss = 0.00366293
# Iteration 54, loss = 0.00365248
# Iteration 55, loss = 0.00364461
# Iteration 56, loss = 0.00364603
# Iteration 57, loss = 0.00364722
# Iteration 58, loss = 0.00364159
# Iteration 59, loss = 0.00363374
# Iteration 60, loss = 0.00364954
# Iteration 61, loss = 0.00364157
# Iteration 62, loss = 0.00364291
# Iteration 63, loss = 0.00364172
# Iteration 64, loss = 0.00362849
# Iteration 65, loss = 0.00362455
# Iteration 66, loss = 0.00362995
# Iteration 67, loss = 0.00362988
# Iteration 68, loss = 0.00363489
# Iteration 69, loss = 0.00363474
# Iteration 70, loss = 0.00364152
# Iteration 71, loss = 0.00362784
# Iteration 72, loss = 0.00362709
# Iteration 73, loss = 0.00362981
# Iteration 74, loss = 0.00363112
# Iteration 75, loss = 0.00363587
# Iteration 76, loss = 0.00363098
# Iteration 77, loss = 0.00362188
# Iteration 78, loss = 0.00363044
# Iteration 79, loss = 0.00363595
# Iteration 80, loss = 0.00362382
# Iteration 81, loss = 0.00362387
# Iteration 82, loss = 0.00362181
# Iteration 83, loss = 0.00362390
# Iteration 84, loss = 0.00362429
# Iteration 85, loss = 0.00363101
# Iteration 86, loss = 0.00363259
# Iteration 87, loss = 0.00362991
# Iteration 88, loss = 0.00362824
# Iteration 89, loss = 0.00361747
# Iteration 90, loss = 0.00362707
# Iteration 91, loss = 0.00362942
# Iteration 92, loss = 0.00362338
# Iteration 93, loss = 0.00362742
# Iteration 94, loss = 0.00362454
# Iteration 95, loss = 0.00361863
# Iteration 96, loss = 0.00361932
# Iteration 97, loss = 0.00361835
# Iteration 98, loss = 0.00362473
# Iteration 99, loss = 0.00361939
# Iteration 100, loss = 0.00362259
# Iteration 101, loss = 0.00362193
# Iteration 102, loss = 0.00362723
# Iteration 103, loss = 0.00362632
# Iteration 104, loss = 0.00362197
# Iteration 105, loss = 0.00362712
# Iteration 106, loss = 0.00362660
# Iteration 107, loss = 0.00362234
# Iteration 108, loss = 0.00361747
# Iteration 109, loss = 0.00362985
# Iteration 110, loss = 0.00362827
# Training loss did not improve more than tol=0.000001 for 20 consecutive epochs. Stopping.

# %%
predictions = regr.predict(X_test)

# %%
# Reverse transform predictions and actual values ahead of error calculation
predictions = predictions*(y_max-y_min)+y_min
y_test = y_test*(y_max-y_min)+y_min
print("RMSE: ")
print(np.sqrt(mean_squared_error(predictions, y_test)))
# Out:
# RMSE:
# 6.364677010778086e-05

# %%
# Compare prediction statistics with 
stats = {'min': np.min(predictions),
         'max': np.max(predictions),
         'median': np.median(predictions),
         'q1': np.percentile(predictions, 25),
         'q3': np.percentile(predictions, 75)}
print(stats)
# Out:
# {'min': 1.7466591914361386e-05, 'max': 0.00013959734782930977, 'median': 8.382598719548963e-05, 'q1': 7.616939330684809e-05, 'q3': 0.00010324284681824599}
